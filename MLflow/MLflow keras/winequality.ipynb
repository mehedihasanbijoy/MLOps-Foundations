# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature
from mlflow.models import validate_serving_input
from mlflow.models import convert_input_example_to_serving_input
import warnings as wrn
wrn.filterwarnings(action="ignore")

# %%
# load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6

# %%
train, test = train_test_split(data, test_size=.25, random_state=42)

train_x = train.drop(['quality'], axis=1).values
train_y = train[['quality']].values.ravel()

test_x = test.drop(['quality'], axis=1).values
test_y = test[['quality']].values.ravel()

train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=.2,random_state=42)

print(train_x.shape, train_y.shape)
print(valid_x.shape, valid_y.shape)
print(test_x.shape, test_y.shape)

signature = infer_signature(train_x, train_y)
print("---------")
print(signature)
# Out:
# (2938, 11) (2938,)
# (735, 11) (735,)
# (1225, 11) (1225,)
# ---------
# inputs:
#   [Tensor('float64', (-1, 11))]
# outputs:
#   [Tensor('int64', (-1,))]
# params:
#   None

# %%
def train_model(params, epochs, train_x, train_y, valid_x, valid_y):
    """Trains a TensorFlow model using the provided training data and logs the results using MLflow.

    Args:
        params (dict): Dictionary containing hyperparameters: 
            - lr (float) 
            - momentum (float)
        epochs (int): Number of epochs
        train_x (ndarray): Training feature set (shape: [num_samples, num_features])
        train_y (ndarray): Training labels (shape: [num_samples, 1])
        valid_x (ndarray): Validation feature set (shape: [num_samples, num_features]).
        valid_y (ndarray): Validation labels (shape: [num_samples, 1])

    Returns:
        dict: A dictionary containing:
            - loss (float)
            - status (hyperopt.STATUS_OK)
            - model (keras.Sequential)
    """
    
    mean = np.mean(train_x, axis=0)
    var = np.var(train_x, axis=0)
    
    model = keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean, variance=var),
            keras.layers.Dense(64, activation="relu"),
            keras.layers.Dense(1)
        ]
    )
    
    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=params["lr"], momentum=params["momentum"]),
        loss="mean_squared_error",
        metrics=[keras.metrics.RootMeanSquaredError()]
    )
    
    with mlflow.start_run(nested=True):
        model.fit(
            train_x, train_y,
            validation_data=(valid_x, valid_y),
            epochs=epochs,
            batch_size=64
        )
        
        eval_result = model.evaluate(valid_x, valid_y, batch_size=64)
        eval_rmse = eval_result[1]
        
        mlflow.log_params(params)
        
        mlflow.log_metric("eval_rmse", eval_rmse)
        
        mlflow.tensorflow.log_model(model=model, artifact_path="model", signature=signature)
        
        return {
            "loss": eval_rmse,
            "status": STATUS_OK,
            "model": model
        }

# %%
def objective(params):
    results = train_model(
        params=params, epochs=5,
        train_x=train_x, train_y=train_y,
        valid_x=valid_x, valid_y=valid_y
    )
    return results

# %%
space={
    "lr": hp.loguniform("lr", np.log(1e-5), np.log(1e-1)),
    "momentum": hp.uniform("momentum", 0.0, 1.0)
}

# %%
mlflow.set_experiment("wine-quality")

with mlflow.start_run():
    
    # Conduct the hyperparameter search using Hyperopt
    trials = Trials()
    
    best = fmin(
        fn = objective, 
        space=space,
        algo=tpe.suggest, 
        max_evals=6, 
        trials=trials
    )
    
    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]
    
    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    
    mlflow.log_metric("eval_rmse", best_run["loss"])
    
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 22s 502ms/step - loss: 36.1855 - root_mean_squared_error: 6.0154
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38.0548 - root_mean_squared_error: 6.1688
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 38.0736 - root_mean_squared_error: 6.1703 - val_loss: 38.1775 - val_root_mean_squared_error: 6.1788
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 38.8460 - root_mean_squared_error: 6.2327
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.8076 - root_mean_squared_error: 6.1487
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.7776 - root_mean_squared_error: 6.1463 - val_loss: 37.3742 - val_root_mean_squared_error: 6.1134
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 38.7417 - root_mean_squared_error: 6.2243
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.9939 - root_mean_squared_error: 6.0822
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36.9597 - root_mean_squared_error: 6.0794 - val_loss: 36.5894 - val_root_mean_squared_error: 6.0489
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 35.5709 - root_mean_squared_error: 5.9641
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.8207 - root_mean_squared_error: 5.9850
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.8199 - root_mean_squared_error: 5.9850 - val_loss: 35.8226 - val_root_mean_squared_error: 5.9852
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 36.5938 - root_mean_squared_error: 6.0493
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.1753 - root_mean_squared_error: 5.9308
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.1680 - root_mean_squared_error: 5.9302 - val_loss: 35.0731 - val_root_mean_squared_error: 5.9223
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 35.4853 - root_mean_squared_error: 5.9570
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.8211 - root_mean_squared_error: 5.9009
#
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 19s 428ms/step - loss: 32.9918 - root_mean_squared_error: 5.7438
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.5851 - root_mean_squared_error: 4.9319
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 24.4246 - root_mean_squared_error: 4.9148 - val_loss: 5.9031 - val_root_mean_squared_error: 2.4296
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.1508 - root_mean_squared_error: 2.2695
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5159 - root_mean_squared_error: 2.1211
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4807 - root_mean_squared_error: 2.1126 - val_loss: 2.6645 - val_root_mean_squared_error: 1.6323
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9287 - root_mean_squared_error: 1.3888
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5201 - root_mean_squared_error: 1.5863
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5078 - root_mean_squared_error: 1.5825 - val_loss: 2.1734 - val_root_mean_squared_error: 1.4742
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4875 - root_mean_squared_error: 1.5772
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9700 - root_mean_squared_error: 1.4031
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9685 - root_mean_squared_error: 1.4026 - val_loss: 1.8923 - val_root_mean_squared_error: 1.3756
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7545 - root_mean_squared_error: 1.3246
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8398 - root_mean_squared_error: 1.3557
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8367 - root_mean_squared_error: 1.3545 - val_loss: 1.7016 - val_root_mean_squared_error: 1.3044
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3639 - root_mean_squared_error: 1.1678
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7105 - root_mean_squared_error: 1.3067
#
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 18s 420ms/step - loss: 40.5460 - root_mean_squared_error: 6.3676
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 11.4281 - root_mean_squared_error: 3.2116 - val_loss: 1.3503 - val_root_mean_squared_error: 1.1620
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.4985 - root_mean_squared_error: 1.2241
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2191 - root_mean_squared_error: 1.1035
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2085 - root_mean_squared_error: 1.0986 - val_loss: 0.9793 - val_root_mean_squared_error: 0.9896
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4049 - root_mean_squared_error: 1.1853
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9250 - root_mean_squared_error: 0.9609 - val_loss: 0.7900 - val_root_mean_squared_error: 0.8888
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.7557 - root_mean_squared_error: 0.8693
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7269 - root_mean_squared_error: 0.8525
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7269 - root_mean_squared_error: 0.8524 - val_loss: 0.6845 - val_root_mean_squared_error: 0.8274
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.7748 - root_mean_squared_error: 0.8802
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6768 - root_mean_squared_error: 0.8224
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6751 - root_mean_squared_error: 0.8213 - val_loss: 0.6214 - val_root_mean_squared_error: 0.7883
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5542 - root_mean_squared_error: 0.7445
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6181 - root_mean_squared_error: 0.7858
#
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 20s 452ms/step - loss: 36.8068 - root_mean_squared_error: 6.0669
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.9708 - root_mean_squared_error: 4.9564
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 24.3705 - root_mean_squared_error: 4.8918 - val_loss: 4.0441 - val_root_mean_squared_error: 2.0110
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.7820 - root_mean_squared_error: 2.1868
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0799 - root_mean_squared_error: 1.7512
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0361 - root_mean_squared_error: 1.7385 - val_loss: 2.1886 - val_root_mean_squared_error: 1.4794
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.5269 - root_mean_squared_error: 1.2357
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8318 - root_mean_squared_error: 1.3532
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8331 - root_mean_squared_error: 1.3537 - val_loss: 1.9205 - val_root_mean_squared_error: 1.3858
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.6510 - root_mean_squared_error: 1.6282
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7229 - root_mean_squared_error: 1.3111
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7020 - root_mean_squared_error: 1.3033 - val_loss: 1.7387 - val_root_mean_squared_error: 1.3186
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1116 - root_mean_squared_error: 1.4531
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5769 - root_mean_squared_error: 1.2539
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5685 - root_mean_squared_error: 1.2506 - val_loss: 1.5935 - val_root_mean_squared_error: 1.2623
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2029 - root_mean_squared_error: 1.0968
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5660 - root_mean_squared_error: 1.2500
#
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 19s 434ms/step - loss: 32.1254 - root_mean_squared_error: 5.6679
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29.5136 - root_mean_squared_error: 5.4315
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.3859 - root_mean_squared_error: 5.4196 - val_loss: 23.9068 - val_root_mean_squared_error: 4.8895
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 26.5365 - root_mean_squared_error: 5.1514
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.7448 - root_mean_squared_error: 4.7676
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.4890 - root_mean_squared_error: 4.7405 - val_loss: 18.1194 - val_root_mean_squared_error: 4.2567
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 18.7154 - root_mean_squared_error: 4.3261
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16.9517 - root_mean_squared_error: 4.1165
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.8581 - root_mean_squared_error: 4.1050 - val_loss: 13.6380 - val_root_mean_squared_error: 3.6930
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 12.4335 - root_mean_squared_error: 3.5261
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.7316 - root_mean_squared_error: 3.5675
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.6796 - root_mean_squared_error: 3.5602 - val_loss: 10.2320 - val_root_mean_squared_error: 3.1988
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11.4100 - root_mean_squared_error: 3.3779
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8772 - root_mean_squared_error: 3.1415
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7859 - root_mean_squared_error: 3.1268 - val_loss: 7.7191 - val_root_mean_squared_error: 2.7783
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.7507 - root_mean_squared_error: 2.7840
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5957 - root_mean_squared_error: 2.7560
#
# Epoch 1/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 19s 435ms/step - loss: 39.3722 - root_mean_squared_error: 6.2747
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.5337 - root_mean_squared_error: 5.7853
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 33.0901 - root_mean_squared_error: 5.7458 - val_loss: 18.8791 - val_root_mean_squared_error: 4.3450
#
# Epoch 2/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 18.3106 - root_mean_squared_error: 4.2791
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.4993 - root_mean_squared_error: 3.9327
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.3389 - root_mean_squared_error: 3.9117 - val_loss: 8.5191 - val_root_mean_squared_error: 2.9187
#
# Epoch 3/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.9886 - root_mean_squared_error: 2.9981
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9322 - root_mean_squared_error: 2.6299
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8887 - root_mean_squared_error: 2.6215 - val_loss: 4.2152 - val_root_mean_squared_error: 2.0531
#
# Epoch 4/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.4713 - root_mean_squared_error: 1.8631
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6435 - root_mean_squared_error: 1.9076
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6201 - root_mean_squared_error: 1.9014 - val_loss: 2.7762 - val_root_mean_squared_error: 1.6662
#
# Epoch 5/5
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.8704 - root_mean_squared_error: 1.6942
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5370 - root_mean_squared_error: 1.5925
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5254 - root_mean_squared_error: 1.5888 - val_loss: 2.2905 - val_root_mean_squared_error: 1.5134
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3511 - root_mean_squared_error: 1.5333
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3068 - root_mean_squared_error: 1.5186
#
# 100%|██████████| 6/6 [01:11<00:00, 11.84s/trial, best loss: 0.7882621884346008]
# Best parameters: {'lr': np.float64(0.012411222045927742), 'momentum': np.float64(0.1996535001783165)}
# Best eval rmse: 0.7882621884346008

# %%
# Inferencing
model_uri = 'runs:/2d55b10dac5a4c7eba5dc8c2ceec7d81/model'

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 495.10it/s]
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[5.695498 ],
#        [7.0315905],
#        [6.3901463],
#        ...,
#        [6.5168996],
#        [6.644665 ],
#        [5.5790186]], dtype=float32)

# %%
# Load model as a PyFuncModel.
model_uri = 'runs:/2d55b10dac5a4c7eba5dc8c2ceec7d81/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)

loaded_model.predict(pd.DataFrame(test_x))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[5.695498 ],
#        [7.0315905],
#        [6.3901463],
#        ...,
#        [6.5168996],
#        [6.644665 ],
#        [5.5790186]], dtype=float32)

# %%
# Register in the model registry
mlflow.register_model(model_uri, "wine-quality")
# Out:
# Successfully registered model 'wine-quality'.
# Created version '1' of model 'wine-quality'.
# <ModelVersion: aliases=[], creation_timestamp=1741427149490, current_stage='None', description=None, last_updated_timestamp=1741427149490, name='wine-quality', run_id='2d55b10dac5a4c7eba5dc8c2ceec7d81', run_link=None, source='file:///d:/MLOpsProjects/MLflow%20keras/mlruns/315369149838321762/2d55b10dac5a4c7eba5dc8c2ceec7d81/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=1>
